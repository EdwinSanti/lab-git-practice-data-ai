# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Edwin Santiago"
reason = "to learn new skills and broaden my horizons for new opportunities"
fun_fact = " Ive always liked computers and the concept of artificial beings and hope to get a job in this field"

print(f"Hi! My name is {name}. I’m excited to learn because {reason}. A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Edwin Santiago. I’m excited to learn because to learn new skills and broaden my horizons for new opportunities. A fun fact about me is:  Ive always liked computers and the concept of artificial beings and hope to get a job in this field.
